# %% [markdown]
# ## Import libraries

# %%
import datetime
from datetime import datetime

import numpy as np
import pandas as pd

import gensim
from gensim.models import HdpModel
from gensim.models.coherencemodel import CoherenceModel

import spacy 
from spacy import displacy

import matplotlib.pyplot as plt

import pickle
import os
import sys
sys.path.append(os.path.join(os.environ['PWD'],'scripts'))

from scrap import get_comments
from preprocess_text import preprocess_raw_comments

# %% [markdown]
# ## Collect comments for January 2022

# %%
data_path = os.path.join(os.environ['PWD'],'data/january_comments.pkl')

if not os.path.isfile(data_path):
    start_date = datetime.strptime('2022-01-01',"%Y-%m-%d")
    end_date = datetime.strptime('2022-02-01',"%Y-%m-%d")
    
    raw_comments = get_comments(start_date, end_date) 
    
    pickling_on = open(data_path,"wb")
    pickle.dump(raw_comments, pickling_on)
    pickling_on.close()
    print('data pickled successfully!')
else:
    pickle_off = open(data_path, 'rb')
    raw_comments = pickle.load(pickle_off)
    print('data unpickled successfully!')
# Out:
# data unpickled successfully!

# %%
len(raw_comments)
# Out:
# 453

# %% [markdown]
# ## Preprocess textual data for analysis

# %%
data_path = os.path.join(os.environ['PWD'],'data/january_comments_processed.pkl')

if not os.path.isfile(data_path):

    preprocessed_text = preprocess_raw_comments(raw_comments) 
    
    pickling_on = open(data_path,"wb")
    pickle.dump(preprocessed_text, pickling_on)
    pickling_on.close()
    print('data pickled successfully!')
else:
    pickle_off = open(data_path, 'rb')
    preprocessed_text = pickle.load(pickle_off)
    print('data unpickled successfully!')
# Out:
# data unpickled successfully!

# %% [markdown]
# ## Analyse rating scores

# %%
preprocessed_text['ratings']
# Out:
#                    pos  neg
# Career Growth      288   83
# Work Satisfaction  297   80
# Job Security       324   63
# Skill Development  325   66
# Work-Life Balance  326   62
# Salary & Benefits  351   50
# Company Culture    382   35

# %% [markdown]
# - Positive and Negative categories are highly negatively correlated
# - Overall employees are mostly satisfied with company culture, salary and benefits
# - Overall employees are mostly dissatisfied with career growth and work satisfaction

# %% [markdown]
# ## Analyse comments

# %% [markdown]
# ### Positive comments

# %%
data_path = os.path.join(os.environ['PWD'],'data/pos_comments_HdpModel.pkl')

if not os.path.isfile(data_path):
    
    hdp_model = HdpModel(corpus=preprocessed_text['pos_corpus'], 
                                        id2word=preprocessed_text['pos_dictionary'],chunksize=10)
    
    coh_model = CoherenceModel(model=hdp_model, texts=preprocessed_text['pos_texts'], 
                        dictionary=preprocessed_text['pos_dictionary'],coherence='c_v')

    coherence = coh_model.get_coherence()  # get coherence value 
        
    pos_topic_model = {}
    pos_topic_model['coherence'] = coherence
    pos_topic_model['coh_model'] = coh_model
    pos_topic_model['hdp_model'] = hdp_model
    
    pickling_on = open(data_path,"wb")
    pickle.dump(pos_topic_model, pickling_on)
    pickling_on.close()
    print('data pickled successfully!')
else:
    pickle_off = open(data_path, 'rb')
    pos_topic_model = pickle.load(pickle_off)
    print('data unpickled successfully!')
# Out:
# data unpickled successfully!

# %%
print('Number of topics: {}, coherence score: {}.'.format(pos_topic_model['hdp_model'].get_topics().shape[0],pos_topic_model['coherence']))
# Out:
# Number of topics: 150, coherence score: 0.7395163734824113.

# %% [markdown]
# Let choose 5 most significant topics.

# %%
n_topics = 5
hdp_model = pos_topic_model['hdp_model']
hdp_model.optimal_ordering()
dictionary = preprocessed_text['pos_dictionary']

# %%
data_frame = pd.DataFrame()
for i in range(n_topics):
    data_frame['Topic'+str(i)] = pd.Series(index=dictionary.values(),data=hdp_model.get_topics()[i]).sort_values(ascending=False).index.values

# %%
data_frame.iloc[:20]
# Out:
#         Topic0           Topic1          Topic2            Topic3  \
# 0      initial           urgent        festival              come
# 1      believe           vedika             try           company
# 2         role            leave  huge_cafeteria            honest
# 3      process        situation           extra     great_company
# 4    literally          holiday      atmosphere  customer_service
# 5      compare           people         voucher              icqa
# 6   manipulate         customer          minute              fair
# 7        skill        excellent             bad              role
# 8         past       nice_place           money              obey
# 9        woman      drastically       marketing         knowledge
# 10      logoff             past            lead             apply
# 11        high             step           world              poor
# 12  department             like         overall              pull
# 13       fever          comfort       assistant          dispatch
# 14     goodbye          working       feel_like           chilled
# 15    consider          company              ot               fun
# 16      comany               ok         fresher               new
# 17     receive      accordingly           share              tech
# 18        year       rotational             ctc             sweet
# 19    overtime  security_depend      supportive              perk
#
#           Topic4
# 0           team
# 1        culture
# 2         expect
# 3          theek
# 4   organization
# 5            bad
# 6        resolve
# 7      feel_like
# 8     extraction
# 9    environment
# 10           old
# 11        purely
# 12        amozon
# 13    background
# 14        metric
# 15  transparency
# 16         truly
# 17      optional
# 18    reasonable
# 19          book

# %% [markdown]
# It is quite hard to determine topics from given words

# %%
data = pd.DataFrame(columns=['Topic','prob','index'])
for index, i in enumerate(hdp_model[preprocessed_text['pos_corpus']]):
    for j in i:
        data.loc[data.shape[0]] = [j[0],j[1],index]

# %%
data = data.sort_values(by=['Topic','prob'],ascending=[True,False])

# %%
for topic in range(n_topics):
    print('Topic {}, most representative comments:'.format(topic))
    comments = data.loc[data.Topic==topic]['index']
    comments = comments[:min(len(comments),5)]
    for comment in comments:
        print('{}: {}'.format(comment, preprocessed_text['pos_texts_comment'][int(comment)].text.strip()))
    print('\n')
# Out:
# Topic 0, most representative comments:
# 112.0: Literally nothing to like about this role.This role doesn't make any sense.you will not even get reasons for what and why are you doing your job. Unnecessarily Extremely high pressure environment.0% job security.worst work culture.They don't give leave.I was COVID positive and was having 103 F fever.They didn't give me leave untill I gave them my reports.They manipulate you by saying shrinkage target.Even if someone is dead in your family.They will give this shrinkage nonsense.Growth in this process is like mission impossible.They lure you by their sweet talk in initial days but after some time they show their true colours.This process is very much infamous in Amazon itself.Other processes don't even consider this process.If you think that you will take internal transfer after sometime,then it is not possible.No one even call you back.I literally wasted my whole year over here.Guys please do not apply for this role.Its a trap.you will think that it's ok it's amazon,but you are just gonna waste your time and energy over here and if you join her just say goodbye to you mental health.
# 92.0: Amazon treats everyone literally as a disposable product. You will be used to the limits in greed for getting promoted in 1.5 years if you fail all failures will be blamed on you to through you out using a mechanism called FOCUS. Sounds ironic bit that's what the reality is sad very sad
# 2.0: Good company for skill development
# 348.0: I like to work with your comany
# 283.0: The benefits, workflow process and hardware provided.
#
#
# Topic 1, most representative comments:
# 220.0: Company is amazing , and every company works with mixup of good and bad people who makes the work culture . Good people help & support others as well to grow along with them whereas bad and mean people only think about their self growth.
# 420.0: Great culture, company will only push you to higher level if you are doing good
# 103.0: Work environment is Amazon.easy to get leaves even in some urgent situation
# 27.0: Amazon is a excellent process and company i really liked to work with this company. If I will get chance in future to work with this company i will definitely go with that
# 152.0: Excellent company
#
#
# Topic 2, most representative comments:
# 418.0: It is overall a good job as a fresher.
# Work is good. You will not do extra work for a single minute. You will get extra money for every extra hour you give to company.Benifits and leaves are really impressive.
# 34.0: Best company , good atmosphere, good team members
# 148.0: My process is very bad.
# 80.0: The best thing about amazon that they hire fresh people at a decent CTC and has to offer a variety of job roles if you focus on your performance. Company policies are employee-centric and their work culture is healthy to maintain your mental well being and a work-life balance.
# 414.0: Exceptional atmosphere with world class college's and infrastructure
#
#
# Topic 3, most representative comments:
# 151.0: The organization where we can work freely,the cluture and benefits which company providing is truly awasome,but when its coming job security,since am in contract we can't the assured job security. Overall experience in Amazon is cool though!!
# 433.0: I absolutely enjoy working for Amazon, comes with multiple outstanding benefits . Very supportive every step of the way,   A lot of knowledge to learn about the company.
# 5.0: Amazon is a good company to work.But ML data associate role is not much intresting to work for. Very boaring job..no growth no skills. Don't apply for it.
# 203.0: Work culture is good even if you work in its customers service it doesn't seem like typical BPO. The place is cool and leadership treat and communicate with you respectfully. Coming to growth part growth is possible only if you have good performance and process knowledge as when internal posting comes almost whole site apply for that and you need to have exceptional past performance and knowledge of process and I think that's fair.
# 190.0: I like the company benefits and the work culture.
#
#
# Topic 4, most representative comments:
# 336.0: Honestly, no words can purely describe how being a part of Amazon feels like! Although it's only been a year for me, it feels like this is a place to grow and learn together.
# 62.0: I love everything about being a part of Amazon team.
# Its the best place to work in.
# 263.0: Pay, team, management
# 330.0: Great team. Work life balance.
# 335.0: good work culture and good WLB at least for my team.

# %% [markdown]
# It is also hard to determine topics from given examples.

# %% [markdown]
# ### Negative comments

# %%
data_path = os.path.join(os.environ['PWD'],'data/neg_comments_HdpModel.pkl')

if not os.path.isfile(data_path):
    
    hdp_model = HdpModel(corpus=preprocessed_text['neg_corpus'], 
                                        id2word=preprocessed_text['neg_dictionary'],chunksize=10)
    
    coh_model = CoherenceModel(model=hdp_model, texts=preprocessed_text['neg_texts'], 
                        dictionary=preprocessed_text['neg_dictionary'],coherence='c_v')

    coherence = coh_model.get_coherence()  # get coherence value 
        
    neg_topic_model = {}
    neg_topic_model['coherence'] = coherence
    neg_topic_model['coh_model'] = coh_model
    neg_topic_model['hdp_model'] = hdp_model
    
    pickling_on = open(data_path,"wb")
    pickle.dump(neg_topic_model, pickling_on)
    pickling_on.close()
    print('data pickled successfully!')
else:
    pickle_off = open(data_path, 'rb')
    neg_topic_model = pickle.load(pickle_off)
    print('data unpickled successfully!')
# Out:
# data unpickled successfully!

# %%
print('Number of topics: {}, coherence score: {}.'.format(neg_topic_model['hdp_model'].get_topics().shape[0],neg_topic_model['coherence']))
# Out:
# Number of topics: 150, coherence score: 0.7725791113454047.

# %%
n_topics = 5
hdp_model = neg_topic_model['hdp_model']
hdp_model.optimal_ordering()
dictionary = preprocessed_text['neg_dictionary']
    
data_frame = pd.DataFrame()
for i in range(n_topics):
    data_frame['Topic'+str(i)] = pd.Series(index=dictionary.values(),data=hdp_model.get_topics()[i]).sort_values(ascending=False).index.values
    
data_frame.iloc[:20]
# Out:
#          Topic0       Topic1       Topic2                Topic3  \
# 0       one.you       happen      quarter           calculation
# 1       indians       reason         need           performance
# 2        change        state       totali           requirement
# 3          want    excellent    condition  contractual_employee
# 4      schedule       follow          let                select
# 5           new           si        noida              volatile
# 6         apply      utilise        pstam            escalation
# 7          like      finally  growth_slow                  know
# 8        number         jeff    beautiful            department
# 9   opportunity        shift        india                comany
# 10     employee  challenging         lack                unlike
# 11      company       manger         grow                 noida
# 12         hide        think    excessive          famous,,when
# 13     pandemic       ignore       report               indians
# 14  performance      problem        agree                   thr
# 15  night_shift         team       shoulf                   org
# 16          let         love        exact             available
# 17        proof         have           na               exploit
# 18         jeff       orient       joinee               amsazon
# 19       unjust          get          roc                  have
#
#                 Topic4
# 0              degrade
# 1                 ball
# 2                thwre
# 3   growth_opportunity
# 4               letter
# 5                proud
# 6          frustration
# 7              extreme
# 8                  few
# 9                fault
# 10               month
# 11              glitch
# 12          absolutely
# 13                work
# 14                 you
# 15           mandatory
# 16         growth_slow
# 17         gangarampur
# 18              rotate
# 19            directly

# %% [markdown]
# It is quite hard to determine topics from given words

# %%
data = pd.DataFrame(columns=['Topic','prob','index'])
for index, i in enumerate(hdp_model[preprocessed_text['neg_corpus']]):
    for j in i:
        data.loc[data.shape[0]] = [j[0],j[1],index]
        
data = data.sort_values(by=['Topic','prob'],ascending=[True,False])

for topic in range(n_topics):
    print('Topic {}, most representative comments:'.format(topic))
    comments = data.loc[data.Topic==topic]['index']
    comments = comments[:min(len(comments),5)]
    for comment in comments:
        print('{}: {}'.format(comment, preprocessed_text['neg_texts_comment'][int(comment)].text.strip()))
    print('\n')
# Out:
# Topic 0, most representative comments:
# 41.0: When you join they will treat you well for 2-3 months but after that, they will show their true colours. Enormous work pressure and you will be forced to achieve their customer satisfaction goals which are way beyond achievable. Jeff wants Amazon to be the world's most customer eccentric company but don't want to pay for it. Compensation is way below the market standards. There is no chance for growth even some of the managers agreed on. They will change your shift and schedule whenever they want and they always had the same answer for this "Business requirement".  They always say we will listen to issues and they do listen after making changes which certainly makes their employee's life hell. I think Amazon is just exploiting Indians and taking advantage of cheap labour
# 80.0: Internal employees are taken leverage in all terms. Moving to a new team within org is too difficult and also hiring manager pay less for internal transfer than externally hired candidate, which is bit annoying.
# 124.0: I have never experienced any dislike from Amazon. Every thing is best if we joined in Amazon like reputated companies.
# 134.0: Compensation poor work time heavy kra hidden
# 216.0: Slow growth opportunity
#
#
# Topic 1, most representative comments:
# 263.0: Continuing the above, I got through the interview process, and got selected. The HR had told that she would get back to be with the offer letter, but never turned up! I kept following up and finally they came up with an email stating that I’m not eligible for rehire! I asked them the reasons and all the reasons they gave were not true. I wrote back to them with the proper reasons and attachments and proofs telling that their reasons are all not true at all! After so many follow ups, the finally put me to HRBP team! And this team never responded to me there after! I followed up for almost 3 months and finally I had to give up! I had never expected this kind of response from such a huge company like AMAZON! More over I was my dream company and I loved everything about the company even when I was working in the company.. But what happened to me in the end is ready very bad I hope this doesn’t happen to any other person who loves Amazon!
# 96.0: There is a lot of favorism happening within. The role gets very monotonous and nothing different to improve or utilise your skill set. The Appraisal would be another downside.
#
#
# Topic 2, most representative comments:
# 147.0: No iam like you job. Noida
# 328.0: Shift work, rotates every quarter but mostly evening/night shift as I support NA & UK region
# 135.0: We can't grow our skill if we didn't got promoted if it doesn't happen we need to start from our initial stage on our career side
# 88.0: Due to politics prevalent , the manager won't let you apply for inside jobs nor let you grow up in the same field. There will be stagnation in the work post 1.5 years and you do repeated work day by day. Promotion criteria in Amazon is too strict and they need to reevaluate it. Salary compensation is too low for such a huge workload and because of low base pay the hike doesn't make much difference.
#
#
# Topic 3, most representative comments:
# 320.0: contractual employee.
# 21.0: Metrics calculation....
# 208.0: You will always be surrounded by escalations, warning letters & you never know, you can be fired at any time. For contractual employees, they rarely convert people into permanent role though they claim conversion can happen on the basis of performance....but that's untrue.
#
#
# Topic 4, most representative comments:
# 156.0: Absolutely nothing but the career growth in this role will take longer than expected. And need extreme dedication unlike other companies.
# 0.0: Nothing this company is the best.i loved working here.

# %% [markdown]
# It is also hard to determine topics from given examples. Some topics have only 2 examples assigned to them.
